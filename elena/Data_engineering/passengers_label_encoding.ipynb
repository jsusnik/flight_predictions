# %%
import pandas as pd
import numpy as np

# %%
flights = pd.read_csv('flights_2019_pass.csv')

# %%
flights.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2019-01-16                 AA                 AA          AA
# 1  2019-01-05                 AA                 AA          AA
# 2  2019-12-08                 AA                 AA          AA
# 3  2019-12-31                 DL                 DL          DL
# 4  2019-01-28                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                1339                AA   N943NN               1339
# 1                2179                AA   N746UW               2179
# 2                 798                AA   N128UW                798
# 3                 453                DL   N179DN                453
# 4                1764                WN   N786SW               1764
#
#    origin_airport_id origin  ... day_of_the_week  origin_wind_speed  \
# 0              12892    LAX  ...       Wednesday               11.9
# ...

# %%
column_names = list(flights.columns.values)

# %%
print(column_names)
# Out:
# ['fl_date', 'mkt_unique_carrier', 'branded_code_share', 'mkt_carrier', 'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num', 'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name', 'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time', 'dep_time', 'dep_delay', 'taxi_out', 'wheels_off', 'wheels_on', 'taxi_in', 'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled', 'cancellation_code', 'diverted', 'dup', 'crs_elapsed_time', 'actual_elapsed_time', 'air_time', 'flights', 'distance', 'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay', 'first_dep_time', 'total_add_gtime', 'longest_add_gtime', 'day_of_the_week', 'origin_wind_speed', 'origin_visibility', 'origin_conditions', 'dest_wind_speed', 'dest_visibility', 'dest_conditions', 'holiday', 'month', 'passengers']

# %%
columns = ['origin_airport_id', 'dest_airport_id', 'origin_city_name','dest_city_name', 'distance', 'day_of_the_week', 'origin_wind_speed', 'origin_visibility', 'origin_conditions', 'dest_wind_speed', 'dest_visibility', 'dest_conditions', 'holiday','arr_delay', 'passengers', 'month']

# %%
df_flights = flights[columns]

# %%
df_flights.head()
# Out:
#    origin_airport_id  dest_airport_id origin_city_name     dest_city_name  \
# 0              12892            12264      los angeles         washington
# 1              12266            11298          houston  dallas/fort worth
# 2              11278            11057       washington          charlotte
# 3              12478            12892         new york        los angeles
# 5              13232            12191          chicago            houston
#
#    distance day_of_the_week  origin_wind_speed  origin_visibility  \
# 0    2288.0       Wednesday               11.9                4.9
# 1     224.0        Saturday                8.2                9.8
# 2     331.0          Sunday               11.1                9.9
# 3    2475.0         Tuesday               19.3                9.6
# 5     937.0         Tuesday               16.8                9.7
#
#         origin_conditions  dest_wind_speed  dest_visibility   dest_conditions  \
# ...

# %%
df_flights['arr_delay'].isnull().value_counts()
# Out:
# False    102224
# Name: arr_delay, dtype: int64

# %%
df_flights = df_flights.dropna()

# %%
df_flights['arr_delay'].isnull().value_counts()
# Out:
# False    102224
# Name: arr_delay, dtype: int64

# %%
def label_encoding(df, column):
    df[column] = df[column].astype('category')
    df[column] = df[column].cat.codes.astype('category')
    return df[column]

# %%
df_flights['origin_city_name'] = label_encoding(df_flights, 'origin_city_name')

# %%
df_flights['dest_city_name'] = label_encoding(df_flights, 'dest_city_name')

# %%
df_flights['day_of_the_week'] = label_encoding(df_flights, 'day_of_the_week')

# %%
df_flights['origin_conditions'] = label_encoding(df_flights, 'origin_conditions')

# %%
df_flights['dest_conditions'] = label_encoding(df_flights, 'dest_conditions')

# %%
df_flights['holiday'] = label_encoding(df_flights, 'holiday')

# %%
df_flights.head()
# Out:
#    origin_airport_id  dest_airport_id origin_city_name dest_city_name  \
# 0              12892            12264                6              9
# 1              12266            11298                5              3
# 2              11278            11057                9              1
# 3              12478            12892                7              6
# 5              13232            12191                2              5
#
#    distance day_of_the_week  origin_wind_speed  origin_visibility  \
# 0    2288.0               6               11.9                4.9
# 1     224.0               2                8.2                9.8
# 2     331.0               3               11.1                9.9
# 3    2475.0               5               19.3                9.6
# 5     937.0               5               16.8                9.7
#
#   origin_conditions  dest_wind_speed  dest_visibility dest_conditions holiday  \
# ...

# %%
df_flights.dtypes
# Out:
# origin_airport_id       int64
# dest_airport_id         int64
# origin_city_name     category
# dest_city_name       category
# distance              float64
# day_of_the_week      category
# origin_wind_speed     float64
# origin_visibility     float64
# origin_conditions    category
# dest_wind_speed       float64
# dest_visibility       float64
# dest_conditions      category
# holiday              category
# arr_delay             float64
# passengers              int64
# month                   int64
# dtype: object

# %%
df_flights.to_csv('delta_encoded.csv', sep=",", index = False)

# %%
df_flights[df_flights.columns].corr()['arr_delay'][:]
# Out:
# origin_airport_id    0.026619
# dest_airport_id      0.026751
# distance            -0.050578
# origin_wind_speed    0.067434
# origin_visibility   -0.106728
# dest_wind_speed      0.073809
# dest_visibility     -0.107925
# arr_delay            1.000000
# passengers          -0.004881
# month               -0.021818
# Name: arr_delay, dtype: float64
