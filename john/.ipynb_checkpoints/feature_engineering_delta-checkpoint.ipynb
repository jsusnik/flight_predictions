# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
# calendar for holidays
cal = calendar()
holidays = cal.holidays(start='2017-12-31', end='2020-12-31')

# %% [markdown]
# ### Read in data:

# %%
#flights = pd.read_csv('flights_weather_holiday.csv') # 

flights = pd.read_csv('Delta_data.csv') # delta airlines specific, all months, 2018-2019 (top 10 origin/dest)
#flights = pd.read_csv('Delta_test.csv') # delta airlines specific, all months, 2018-2019 (top 10 origin/dest)

passengers = pd.read_csv('passengers_jan-dec_18-19.csv') # for all airlines, for jan-dec, 2018-2019 (top 10 origin/dest)

# %%
flights = flights.sort_values(by=['fl_date'])

# %%
holidays
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-15', '2018-02-19', '2018-05-28',
#                '2018-07-04', '2018-09-03', '2018-10-08', '2018-11-12',
#                '2018-11-22', '2018-12-25', '2019-01-01', '2019-01-21',
#                '2019-02-18', '2019-05-27', '2019-07-04', '2019-09-02',
#                '2019-10-14', '2019-11-11', '2019-11-28', '2019-12-25',
#                '2020-01-01', '2020-01-20', '2020-02-17', '2020-05-25',
#                '2020-07-03', '2020-09-07', '2020-10-12', '2020-11-11',
#                '2020-11-26', '2020-12-25'],
#               dtype='datetime64[ns]', freq=None)

# %%
#flights['holiday'] = flights['fl_date'].isin(holidays)

# %%
flights
# Out:
#            fl_date mkt_carrier  origin_airport_id   origin_city_name  \
# 305935  2018-01-01          DL              13930            chicago
# 305763  2018-01-01          DL              12892        los angeles
# 305762  2018-01-01          DL              11298  dallas/fort worth
# 305761  2018-01-01          DL              14747            seattle
# 305760  2018-01-01          DL              14747            seattle
# ...            ...         ...                ...                ...
# 163     2019-12-31          DL              14747            seattle
# 162     2019-12-31          DL              12478           new york
# 161     2019-12-31          DL              12892        los angeles
# 174     2019-12-31          DL              12266            houston
# 0       2019-12-31          DL              12953           new york
#
#         dest_airport_id     dest_city_name  crs_dep_time  crs_arr_time  \
# 305935            10397            atlanta           705          1010
# 305763            11298  dallas/fort worth           950          1504
# 305762            12892        los angeles           705           845
# 305761            11292             denver          1355          1746
# 305760            11292             denver          1906          2256
# ...                 ...                ...           ...           ...
# 163               12892        los angeles          1543          1815
# 162               12892        los angeles           945          1310
# 161               10397            atlanta          1150          1902
# 174               10397            atlanta          1110          1409
# 0                 13930            chicago          1110          1257
#
#         dep_time  arr_time  dep_delay  arr_delay  crs_elapsed_time  \
# 305935     704.0     948.0       -1.0      -22.0             125.0
# 305763     946.0    1438.0       -4.0      -26.0             194.0
# 305762     702.0     823.0       -3.0      -22.0             220.0
# 305761    1355.0    1732.0        0.0      -14.0             171.0
# 305760    1930.0    2300.0       24.0        4.0             170.0
# ...          ...       ...        ...        ...               ...
# 163       1542.0    1759.0       -1.0      -16.0             152.0
# 162        940.0    1225.0       -5.0      -45.0             385.0
# 161       1155.0    1854.0        5.0       -8.0             252.0
# 174       1104.0    1344.0       -6.0      -25.0             119.0
# 0         1114.0    1228.0        4.0      -29.0             167.0
#
#         actual_elapsed_time  air_time  distance  carrier_delay  weather_delay  \
# 305935                104.0      85.0     606.0            NaN            NaN
# 305763                172.0     146.0    1235.0            NaN            NaN
# 305762                201.0     171.0    1235.0            NaN            NaN
# 305761                157.0     126.0    1024.0            NaN            NaN
# 305760                150.0     123.0    1024.0            NaN            NaN
# ...                     ...       ...       ...            ...            ...
# 163                   137.0     114.0     954.0            NaN            NaN
# 162                   345.0     321.0    2475.0            NaN            NaN
# 161                   239.0     222.0    1947.0            NaN            NaN
# 174                   100.0      81.0     689.0            NaN            NaN
# 0                     134.0     110.0     733.0            NaN            NaN
#
#         nas_delay  security_delay  late_aircraft_delay  origin_wind_speed  \
# 305935        NaN             NaN                  NaN               12.7
# 305763        NaN             NaN                  NaN                5.6
# 305762        NaN             NaN                  NaN               15.0
# 305761        NaN             NaN                  NaN                7.0
# 305760        NaN             NaN                  NaN                7.0
# ...           ...             ...                  ...                ...
# 163           NaN             NaN                  NaN               20.0
# 162           NaN             NaN                  NaN               14.4
# 161           NaN             NaN                  NaN                4.2
# 174           NaN             NaN                  NaN                8.9
# 0             NaN             NaN                  NaN               14.4
#
#         origin_visibility origin_conditions  dest_wind_speed  dest_visibility  \
# 305935                9.9             Clear             14.6              9.9
# 305763                4.4             Clear             15.0              9.9
# 305762                9.9  Partially cloudy              5.6              4.4
# 305761                9.8  Partially cloudy             12.3              9.1
# 305760                9.8  Partially cloudy             12.3              9.1
# ...                   ...               ...              ...              ...
# 163                   9.4    Rain, Overcast              4.2              9.9
# 162                   9.6    Rain, Overcast              4.2              9.9
# 161                   9.9             Clear             18.6              9.9
# 174                   9.3             Clear             18.6              9.9
# 0                     9.6    Rain, Overcast             25.3              7.9
#
#          dest_conditions day_of_the_week  holiday
# 305935  Partially cloudy          Monday     True
# 305763  Partially cloudy          Monday     True
# 305762             Clear          Monday     True
# 305761  Partially cloudy          Monday     True
# 305760  Partially cloudy          Monday     True
# ...                  ...             ...      ...
# 163                Clear         Tuesday     True
# 162                Clear         Tuesday     True
# 161                Clear         Tuesday     True
# 174                Clear         Tuesday     True
# 0         Snow, Overcast         Tuesday     True
#
# [305936 rows x 29 columns]

# %%
flights.columns
# Out:
# Index(['fl_date', 'mkt_carrier', 'origin_airport_id', 'origin_city_name',
#        'dest_airport_id', 'dest_city_name', 'crs_dep_time', 'crs_arr_time',
#        'dep_time', 'arr_time', 'dep_delay', 'arr_delay', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance', 'carrier_delay',
#        'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay',
#        'origin_wind_speed', 'origin_visibility', 'origin_conditions',
#        'dest_wind_speed', 'dest_visibility', 'dest_conditions',
#        'day_of_the_week', 'holiday'],
#       dtype='object')

# %%
flights['fl_date']
# Out:
# 305935    2018-01-01
# 305763    2018-01-01
# 305762    2018-01-01
# 305761    2018-01-01
# 305760    2018-01-01
#              ...
# 163       2019-12-31
# 162       2019-12-31
# 161       2019-12-31
# 174       2019-12-31
# 0         2019-12-31
# Name: fl_date, Length: 305936, dtype: object

# %%
flights['dest_city_name'].unique() # will have to rename the city names to coincide with passengers
# Out:
# array(['atlanta', 'dallas/fort worth', 'los angeles', 'denver', 'seattle',
#        'new york', 'houston', 'charlotte', 'chicago', 'washington'],
#       dtype=object)

# %%
passengers.head()
# Out:
#    departures_scheduled  departures_performed  seats  passengers  freight  \
# 0                    54                    53   9437        7536    49137
# 1                    54                    54   4104        3583        0
# 2                    54                    54   4104        3841        0
# 3                    54                    53   9275        7655    12897
# 4                    54                    49   7721        6146    13844
#
#    mail  distance  ramp_to_ramp  air_time unique_carrier  \
# 0  3689      1660         11961     10273             AS
# 1     0      1235         12055      9782             OO
# 2     0       954          9305      7223             OO
# 3     0      1452          9941      8887             WN
# 4  1904       760          6457      4907             DL
#
#       unique_carrier_name  aircraft_type  origin_airport_id  \
# 0    Alaska Airlines Inc.            888              14747
# 1   SkyWest Airlines Inc.            673              11298
# 2   SkyWest Airlines Inc.            673              14747
# 3  Southwest Airlines Co.            614              11292
# 4    Delta Air Lines Inc.            694              10397
#
#    origin_city_market_id       origin_city_name  dest_airport_id  \
# 0                  30559            Seattle, WA            11298
# 1                  30194  Dallas/Fort Worth, TX            12892
# 2                  30559            Seattle, WA            12892
# 3                  30325             Denver, CO            12264
# 4                  30397            Atlanta, GA            12478
#
#    dest_city_market_id         dest_city_name  year  month
# 0                30194  Dallas/Fort Worth, TX  2018      1
# 1                32575        Los Angeles, CA  2018      1
# 2                32575        Los Angeles, CA  2018      1
# 3                30852         Washington, DC  2018      1
# 4                31703           New York, NY  2018      1

# %% [markdown]
# # Set some new columns:
# - Year
# - Month
# - Weekday (as number)
# - Hour (24hour clock)
# - Holiday (1 for yes, 0 for no)
# - Holiday_Weekend (1 for yes, 0 for no)

# %%
# # year
# year_vector = []
# for i in flights['fl_date'].values:
#     year_vector.append(i[0:4])

# flights['year'] = year_vector

# %%
# year - for TEST DATA (for some reason different..)
year_vector = []
for i in flights['fl_date'].values:
    year_vector.append(i[-4:])

flights['year'] = year_vector

# %%
flights['year']
# Out:
# 305935    1-01
# 305763    1-01
# 305762    1-01
# 305761    1-01
# 305760    1-01
#           ...
# 163       2-31
# 162       2-31
# 161       2-31
# 174       2-31
# 0         2-31
# Name: year, Length: 305936, dtype: object

# %%
# # month
# month_vector = []
# for i in flights['fl_date'].values:
#     month_vector.append(i[5:7])

# flights['month'] = month_vector

# %%
flights
# Out:
#            fl_date mkt_carrier  origin_airport_id   origin_city_name  \
# 305935  2018-01-01          DL              13930            chicago
# 305763  2018-01-01          DL              12892        los angeles
# 305762  2018-01-01          DL              11298  dallas/fort worth
# 305761  2018-01-01          DL              14747            seattle
# 305760  2018-01-01          DL              14747            seattle
# ...            ...         ...                ...                ...
# 163     2019-12-31          DL              14747            seattle
# 162     2019-12-31          DL              12478           new york
# 161     2019-12-31          DL              12892        los angeles
# 174     2019-12-31          DL              12266            houston
# 0       2019-12-31          DL              12953           new york
#
#         dest_airport_id     dest_city_name  crs_dep_time  crs_arr_time  \
# 305935            10397            atlanta           705          1010
# 305763            11298  dallas/fort worth           950          1504
# 305762            12892        los angeles           705           845
# 305761            11292             denver          1355          1746
# 305760            11292             denver          1906          2256
# ...                 ...                ...           ...           ...
# 163               12892        los angeles          1543          1815
# 162               12892        los angeles           945          1310
# 161               10397            atlanta          1150          1902
# 174               10397            atlanta          1110          1409
# 0                 13930            chicago          1110          1257
#
#         dep_time  arr_time  dep_delay  arr_delay  crs_elapsed_time  \
# 305935     704.0     948.0       -1.0      -22.0             125.0
# 305763     946.0    1438.0       -4.0      -26.0             194.0
# 305762     702.0     823.0       -3.0      -22.0             220.0
# 305761    1355.0    1732.0        0.0      -14.0             171.0
# 305760    1930.0    2300.0       24.0        4.0             170.0
# ...          ...       ...        ...        ...               ...
# 163       1542.0    1759.0       -1.0      -16.0             152.0
# 162        940.0    1225.0       -5.0      -45.0             385.0
# 161       1155.0    1854.0        5.0       -8.0             252.0
# 174       1104.0    1344.0       -6.0      -25.0             119.0
# 0         1114.0    1228.0        4.0      -29.0             167.0
#
#         actual_elapsed_time  air_time  distance  carrier_delay  weather_delay  \
# 305935                104.0      85.0     606.0            NaN            NaN
# 305763                172.0     146.0    1235.0            NaN            NaN
# 305762                201.0     171.0    1235.0            NaN            NaN
# 305761                157.0     126.0    1024.0            NaN            NaN
# 305760                150.0     123.0    1024.0            NaN            NaN
# ...                     ...       ...       ...            ...            ...
# 163                   137.0     114.0     954.0            NaN            NaN
# 162                   345.0     321.0    2475.0            NaN            NaN
# 161                   239.0     222.0    1947.0            NaN            NaN
# 174                   100.0      81.0     689.0            NaN            NaN
# 0                     134.0     110.0     733.0            NaN            NaN
#
#         nas_delay  security_delay  late_aircraft_delay  origin_wind_speed  \
# 305935        NaN             NaN                  NaN               12.7
# 305763        NaN             NaN                  NaN                5.6
# 305762        NaN             NaN                  NaN               15.0
# 305761        NaN             NaN                  NaN                7.0
# 305760        NaN             NaN                  NaN                7.0
# ...           ...             ...                  ...                ...
# 163           NaN             NaN                  NaN               20.0
# 162           NaN             NaN                  NaN               14.4
# 161           NaN             NaN                  NaN                4.2
# 174           NaN             NaN                  NaN                8.9
# 0             NaN             NaN                  NaN               14.4
#
#         origin_visibility origin_conditions  dest_wind_speed  dest_visibility  \
# 305935                9.9             Clear             14.6              9.9
# 305763                4.4             Clear             15.0              9.9
# 305762                9.9  Partially cloudy              5.6              4.4
# 305761                9.8  Partially cloudy             12.3              9.1
# 305760                9.8  Partially cloudy             12.3              9.1
# ...                   ...               ...              ...              ...
# 163                   9.4    Rain, Overcast              4.2              9.9
# 162                   9.6    Rain, Overcast              4.2              9.9
# 161                   9.9             Clear             18.6              9.9
# 174                   9.3             Clear             18.6              9.9
# 0                     9.6    Rain, Overcast             25.3              7.9
#
#          dest_conditions day_of_the_week  holiday  year
# 305935  Partially cloudy          Monday     True  1-01
# 305763  Partially cloudy          Monday     True  1-01
# 305762             Clear          Monday     True  1-01
# 305761  Partially cloudy          Monday     True  1-01
# 305760  Partially cloudy          Monday     True  1-01
# ...                  ...             ...      ...   ...
# 163                Clear         Tuesday     True  2-31
# 162                Clear         Tuesday     True  2-31
# 161                Clear         Tuesday     True  2-31
# 174                Clear         Tuesday     True  2-31
# 0         Snow, Overcast         Tuesday     True  2-31
#
# [305936 rows x 30 columns]

# %%
# month - for TEST DATA (for some reason different..)
month_vector = []
for i in flights['fl_date'].values:
    month_vector.append(i[0:1])

flights['month'] = month_vector

# %%
flights['month']
# Out:
# 305935    2
# 305763    2
# 305762    2
# 305761    2
# 305760    2
#          ..
# 163       2
# 162       2
# 161       2
# 174       2
# 0         2
# Name: month, Length: 305936, dtype: object

# %%
flights['day_of_the_week'].value_counts()
# Out:
# Monday       47273
# Friday       47053
# Thursday     46852
# Wednesday    46286
# Tuesday      46111
# Sunday       41245
# Saturday     31116
# Name: day_of_the_week, dtype: int64

# %%
#
# NOTE: I have commented this out because I believe it might be better to one_hot_encode these to identify the data better
#

# # weekday
# weekday_dict = {
#     'Sunday' : 0,
#     'Monday': 1,
#     'Tuesday' : 2,
#     'Wednesday' : 3,
#     'Thursday' : 4,
#     'Friday' : 5,
#     'Saturday' : 6
# }

# flights['day_of_the_week'] = flights['day_of_the_week'].replace(weekday_dict)
flights['day_of_the_week'].value_counts()
# Out:
# Monday       47273
# Friday       47053
# Thursday     46852
# Wednesday    46286
# Tuesday      46111
# Sunday       41245
# Saturday     31116
# Name: day_of_the_week, dtype: int64

# %%
flights.columns
# Out:
# Index(['fl_date', 'mkt_carrier', 'origin_airport_id', 'origin_city_name',
#        'dest_airport_id', 'dest_city_name', 'crs_dep_time', 'crs_arr_time',
#        'dep_time', 'arr_time', 'dep_delay', 'arr_delay', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance', 'carrier_delay',
#        'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay',
#        'origin_wind_speed', 'origin_visibility', 'origin_conditions',
#        'dest_wind_speed', 'dest_visibility', 'dest_conditions',
#        'day_of_the_week', 'holiday', 'year', 'month'],
#       dtype='object')

# %%
# the data_description says these are:
# crs_dep_time > computer reservation system departure time; the scheduled time of the flight (hhmm format)
# dep_time > the actual departure time (hhmm format)


flights[['crs_dep_time']]
# Out:
#         crs_dep_time
# 305935           705
# 305763           950
# 305762           705
# 305761          1355
# 305760          1906
# ...              ...
# 163             1543
# 162              945
# 161             1150
# 174             1110
# 0               1110
#
# [305936 rows x 1 columns]

# %%
# scheduled_hour (24 hour)
scheduled_flight_hour_of_day = []
for i in flights['crs_dep_time']:
    if (len(str(i))) == 4:
        scheduled_flight_hour_of_day.append((str(i)[0:2]))
    else:
        scheduled_flight_hour_of_day.append((str(i)[0:1]))

flights['scheduled_flight_hour_of_day'] = scheduled_flight_hour_of_day
flights['scheduled_flight_hour_of_day']
# Out:
# 305935     7
# 305763     9
# 305762     7
# 305761    13
# 305760    19
#           ..
# 163       15
# 162        9
# 161       11
# 174       11
# 0         11
# Name: scheduled_flight_hour_of_day, Length: 305936, dtype: object

# %%
# # depature_hour (24 hour)
# # for whatever reason this column is a float
# departure_hour_of_day = []
# for i in flights['dep_time']:
#     if (len(str(i))) > 5:
#         #print(i)
#         departure_hour_of_day.append((str(i)[0:2]))
#     else:
#         #print(i)
#         departure_hour_of_day.append((str(i)[0:1]))

# flights['departure_flight_hour_of_day'] = departure_hour_of_day
# flights['departure_flight_hour_of_day']

# %%
# holiday (1 for yes, 0 for no)
# ELENA ADDED

# %%
# holiday_weekend (1 for yes, 0 for no)

# %%
#
# WIND SPEED UNITS ARE MPH  
# https://www.aopa.org/training-and-safety/students/solo/skills/too-windy
# article above says 20-25 knots can be difficult to fly
#

# %% [markdown]
# # Add `route_info` column to `passengers` and `flights`
# adding a column to contain information about the flight route:
#
#     `route_info = (origin_airport_id, dest_airport_id, year, month)`

# %%
passengers[['origin_airport_id', 'dest_airport_id', 'year', 'month']].head()
# Out:
#    origin_airport_id  dest_airport_id  year  month
# 0              14747            11298  2018      1
# 1              11298            12892  2018      1
# 2              14747            12892  2018      1
# 3              11292            12264  2018      1
# 4              10397            12478  2018      1

# %% [markdown]
# ### Passenger `route_info`

# %%
# route_info = []
# sep = '-'

# # iterate over the entire dataframe, constructing the route_info
# for i in range(len(passengers[['origin_airport_id', 'dest_airport_id', 'year', 'month']])):
#     route_info.append(str(passengers.iloc[i].origin_airport_id) + sep + str(passengers.iloc[i].dest_airport_id) + sep + str(passengers.iloc[i].year) + sep + str(passengers.iloc[i].month))

# passengers['route_info'] = pd.DataFrame(route_info)

# %% [markdown]
# ### Flights `route_info`

# %%
# NOTE************************
# I comment this out because this step takes a while, 
# I believe there's a better way to implement this but for now this works
#

# route_info = []
# sep = '-'

# # iterate over the entire dataframe, constructing the route_info
# for i in range(len(flights[['origin_airport_id', 'dest_airport_id', 'year', 'month']])):
#     route_info.append(str(flights.iloc[i].origin_airport_id) + sep + str(flights.iloc[i].dest_airport_id) + sep + str(flights.iloc[i].year) + sep + str(flights.iloc[i].month))

# flights['route_info'] = pd.DataFrame(route_info)

# %%
#flights.loc[flights['origin_conditions'] == 'Partially cloudy', 'origin_rain'] = 0

# %%
# flights['route_info'].value_counts()[:5]

# %%
# this is an example of a SPECIFIC route, for December 2019 
# CHICAGO, IL to ATLANTA, GA
# passengers[passengers['route_info'] == '13930-10397-2019-12'][[
#     'departures_performed', 
#     'unique_carrier', 'unique_carrier_name', 
#     'aircraft_type', 
#     'origin_airport_id', 'dest_airport_id', 
#     'route_info', 'origin_city_name', 'dest_city_name', 
#     'air_time', 
#     'passengers', 'freight', 'mail'
# ]].sort_values(by=['unique_carrier_name']).head(5)

# %%
flights.head()
# Out:
#            fl_date mkt_carrier  origin_airport_id   origin_city_name  \
# 305935  2018-01-01          DL              13930            chicago
# 305763  2018-01-01          DL              12892        los angeles
# 305762  2018-01-01          DL              11298  dallas/fort worth
# 305761  2018-01-01          DL              14747            seattle
# 305760  2018-01-01          DL              14747            seattle
#
#         dest_airport_id     dest_city_name  crs_dep_time  crs_arr_time  \
# 305935            10397            atlanta           705          1010
# 305763            11298  dallas/fort worth           950          1504
# 305762            12892        los angeles           705           845
# 305761            11292             denver          1355          1746
# 305760            11292             denver          1906          2256
#
#         dep_time  arr_time  dep_delay  arr_delay  crs_elapsed_time  \
# 305935     704.0     948.0       -1.0      -22.0             125.0
# 305763     946.0    1438.0       -4.0      -26.0             194.0
# 305762     702.0     823.0       -3.0      -22.0             220.0
# 305761    1355.0    1732.0        0.0      -14.0             171.0
# 305760    1930.0    2300.0       24.0        4.0             170.0
#
#         actual_elapsed_time  air_time  distance  carrier_delay  weather_delay  \
# 305935                104.0      85.0     606.0            NaN            NaN
# 305763                172.0     146.0    1235.0            NaN            NaN
# 305762                201.0     171.0    1235.0            NaN            NaN
# 305761                157.0     126.0    1024.0            NaN            NaN
# 305760                150.0     123.0    1024.0            NaN            NaN
#
#         nas_delay  security_delay  late_aircraft_delay  origin_wind_speed  \
# 305935        NaN             NaN                  NaN               12.7
# 305763        NaN             NaN                  NaN                5.6
# 305762        NaN             NaN                  NaN               15.0
# 305761        NaN             NaN                  NaN                7.0
# 305760        NaN             NaN                  NaN                7.0
#
#         origin_visibility origin_conditions  dest_wind_speed  dest_visibility  \
# 305935                9.9             Clear             14.6              9.9
# 305763                4.4             Clear             15.0              9.9
# 305762                9.9  Partially cloudy              5.6              4.4
# 305761                9.8  Partially cloudy             12.3              9.1
# 305760                9.8  Partially cloudy             12.3              9.1
#
#          dest_conditions day_of_the_week  holiday  year month  \
# 305935  Partially cloudy          Monday     True  1-01     2
# 305763  Partially cloudy          Monday     True  1-01     2
# 305762             Clear          Monday     True  1-01     2
# 305761  Partially cloudy          Monday     True  1-01     2
# 305760  Partially cloudy          Monday     True  1-01     2
#
#        scheduled_flight_hour_of_day
# 305935                            7
# 305763                            9
# 305762                            7
# 305761                           13
# 305760                           19

# %%
flights.columns
# Out:
# Index(['fl_date', 'mkt_carrier', 'origin_airport_id', 'origin_city_name',
#        'dest_airport_id', 'dest_city_name', 'crs_dep_time', 'crs_arr_time',
#        'dep_time', 'arr_time', 'dep_delay', 'arr_delay', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance', 'carrier_delay',
#        'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay',
#        'origin_wind_speed', 'origin_visibility', 'origin_conditions',
#        'dest_wind_speed', 'dest_visibility', 'dest_conditions',
#        'day_of_the_week', 'holiday', 'year', 'month',
#        'scheduled_flight_hour_of_day'],
#       dtype='object')

# %%
columns_to_drop = [
    #'dup', 
    #'departure_flight_hour_of_day', 
    #'flights'
]

# %%
#flights_to_csv = flights.drop(columns=columns_to_drop)

# %%
#flights.to_csv('delta_flights_.csv')
#flights.to_csv('delta_flights_test.csv')

# %% [markdown]
# # END OF FEATURE ENGINEERING, ONCE FEATURE ENGINEERING IS COMPLETE, ALL CONTENT BELOW WILL BE MOVED TO ANOTHER NOTEBOOK

# %%
#STOP

# %% [markdown]
# ## Passenger Table Analysis
# - Note how there are quite a few airlines with 0 flights scheduled and they still have flights performed, I imagine these flights would contribute to flight delays

# %%
# look at flight types (passengers, freight, mail), as well as the carrier, the air time, and the departure information
#
#

passengers['departures_cancelled'] = passengers['departures_scheduled'] - passengers['departures_performed']
passengers[[
    'departures_cancelled', 'departures_scheduled', 'departures_performed', 'unique_carrier', 'unique_carrier_name', 'air_time', 'passengers', 'freight', 'mail'
]].groupby(by=['unique_carrier'], as_index=True).sum().sort_values(by='departures_cancelled', ascending=False)[:100]
# Out:
#                 departures_cancelled  departures_scheduled  \
# unique_carrier
# AA                               909                 53090
# WN                               755                 23993
# YX                               520                 12255
# OO                               228                  6605
# UA                               181                 33701
# B6                               171                  5005
# AS                               158                  9633
# 9E                               108                  3379
# OH                                97                  2694
# YV                                60                  7368
# DL                                46                 37136
# MQ                                45                  1285
# EV                                45                  1134
# G7                                23                   759
# VX                                22                   656
# CP                                12                  2498
# ZW                                12                   107
# AX                                11                    70
# QX                                 1                   152
# EM                                 0                     4
# PT                                 0                     1
# C5                                 0                     5
# NK                                 0                  4625
# 04Q                                0                    33
# 5X                                 0                   543
# 28Q                                0                     0
# FX                                 0                  1169
# AY                                -1                     0
# WL                                -1                     0
# AMQ                               -1                     0
# AM                                -1                     0
# SE                                -1                     0
# EY                                -1                     0
# KL                                -1                     0
# WI                                -1                     0
# AC                                -1                     0
# 15Q                               -1                     0
# AF                                -1                     0
# 0WQ                               -1                     0
# LF                                -1                     0
# VS                                -2                     0
# BA                                -2                     0
# 5D                                -2                     0
# 13Q                               -2                     0
# N8                                -2                     0
# F9                                -2                  3110
# ABX                               -2                    95
# 09Q                               -3                     0
# 3EQ                               -3                     0
# SY                                -4                     0
# GL                                -5                     0
# PO                                -6                     0
# HA                                -7                     0
# KAH                              -10                   160
# X9                               -10                     0
# TK                               -10                     0
# SQ                               -11                     0
# 27Q                              -12                     0
# 3S                               -13                     0
# P3                               -15                     0
# KD                               -18                     0
# 4B                               -24                     0
# CK                               -39                     0
# KAQ                              -54                     0
# 1WQ                              -54                     0
# LH                               -57                     0
# BR                               -62                     0
# KZ                               -85                     0
# CI                              -130                     0
# CX                              -131                     0
# 5Y                              -186                     0
# RU                              -217                     0
# 8C                              -222                     0
# KE                              -288                     0
# QF                              -315                     0
# OZ                              -387                     0
#
#                 departures_performed  air_time  passengers   freight      mail
# unique_carrier
# AA                             52181   7616905     6977274  20518112  15921137
# WN                             23238   3162328     2914262   8312732         0
# YX                             11735   1046916      585726         0         0
# OO                              6377    786621      367622         0         0
# UA                             33520   5168419     4761833  14765564  16486863
# B6                              4834   1122992      584030         0         0
# AS                              9475   1992831     1317512   3449093   2210369
# 9E                              3271    281534      166821         0         0
# OH                              2597    148552      137991     15276      2367
# YV                              7308    654852      459886       507        85
# DL                             37090   5277127     4891208  30119372  13303229
# MQ                              1240    120311       68579      3262         0
# EV                              1089     97957       52407         0         0
# G7                               736     77967       43648         0         0
# VX                               634    167948       74545         0         0
# CP                              2486    355722      154482         0         0
# ZW                                95      8112        4009         0         0
# AX                                59      2928        2136         0         0
# QX                               151     20895       10062     19133     20521
# EM                                 4       135           0     13934         0
# PT                                 1       102          38         0         0
# C5                                 5       292         189         0         0
# NK                              4625    675888      741619         0         0
# 04Q                               33       534         103         0         0
# 5X                               543     59807           0  18774988    398460
# 28Q                                0         0           0         0         0
# FX                              1169    164192           0  64001423         0
# AY                                 1         0         156     13644         0
# WL                                 1       115           0         0         0
# AMQ                                1        87          31         0         0
# AM                                 1         0         221     20803         0
# SE                                 1         0           0         0         0
# EY                                 1         0           0         0         0
# KL                                 1         0         494         0         0
# WI                                 1       235           0      2282         0
# AC                                 1         0          45         0         0
# 15Q                                1         0           2         0         0
# AF                                 1         0         151     16980         0
# 0WQ                                1       120           2         0         0
# LF                                 1       101           0         0         0
# VS                                 2         0         356         0         0
# BA                                 2         0         401     53431         0
# 5D                                 2         0         122         0         0
# 13Q                                2         0           4         0         0
# N8                                 2       277           0     78380         0
# F9                              3112    448845      488386         0         0
# ABX                               97     12390           0   3549561         0
# 09Q                                3       275         101         0         0
# 3EQ                                3       354          16         0         0
# SY                                 4       906         613         0         0
# GL                                 5       580         324         0         0
# PO                                 6         0           0    144236         0
# HA                                 7      1443        1146    113964         0
# KAH                              170      4865        1138         0         0
# X9                                10      1002         423         0         0
# TK                                10         0           0    859080         0
# SQ                                11         0           0    940648         0
# 27Q                               12      1110          31         0         0
# 3S                                13         0           0   1156639         0
# P3                                15         0           0   1652360         0
# KD                                18      1049           0    579484         0
# 4B                                24       247         125         0         0
# CK                                39         0           0   8498050         0
# KAQ                               54      6185           0   6234487    453347
# 1WQ                               54      2352         799         0         0
# LH                                57         0           0   5724770         0
# BR                                62         0           0   4997258         0
# KZ                                85         0           0  10738502         0
# CI                               130         0           0  13865578         0
# CX                               131         0         543  21899764         0
# 5Y                               186     20809          75  20088801         0
# RU                               217         0           0  16489785         0
# 8C                               222     40632           0  11258511         0
# KE                               288         0           0  22293195         0
# QF                               315         0       44806   8304860         0
# OZ                               387         0           0  24318984         0

# %%
departure_data = passengers[[
    'departures_cancelled', 'departures_scheduled', 'departures_performed', 'unique_carrier', 'unique_carrier_name', 'air_time', 'passengers', 'freight', 'mail'
]].groupby(by=['unique_carrier'], as_index = False).sum().sort_values(by='departures_cancelled', ascending=False)[:100]

# %%
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(30,8.27)})
tips = sns.load_dataset("tips")
ax = sns.barplot(x="unique_carrier", y="departures_cancelled", data=departure_data)

# %% [markdown]
# ### The graph above shows that there are a considerable number of flights that are not scheduled, yet still take place. I've tried to look up information about these flights in the `flights` table but they are hard to track as both the `unique_carrier` and `unique_carrier_name` are not present in the `flights` table

# %%
#flights[flights['op_unique_carrier'] =='OZ']

# %% [markdown]
# ## Flights Table Analysis

# %%
flights.columns
# Out:
# Index(['fl_date', 'mkt_carrier', 'origin_airport_id', 'origin_city_name',
#        'dest_airport_id', 'dest_city_name', 'crs_dep_time', 'crs_arr_time',
#        'dep_time', 'arr_time', 'dep_delay', 'arr_delay', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance', 'carrier_delay',
#        'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay',
#        'origin_wind_speed', 'origin_visibility', 'origin_conditions',
#        'dest_wind_speed', 'dest_visibility', 'dest_conditions',
#        'day_of_the_week', 'holiday', 'year', 'month',
#        'scheduled_flight_hour_of_day'],
#       dtype='object')

# %%
mean_ = flights['arr_delay'].mean()
max_ = flights['arr_delay'].max()
min_ = flights['arr_delay'].min()

print(f'Mean flight delay: {mean_}\nMax flight delay: {max_}\nMin flight delay: {min_}')
# Out:
# Mean flight delay: 5.254269738847005
# Max flight delay: 2692.0
# Min flight delay: -208.0

# %%
sns.histplot(data=flights, x="arr_delay")
# Out:
# <AxesSubplot:xlabel='arr_delay', ylabel='Count'>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() # create a scalar
hist_x = scaler.fit(flights['arr_delay'].values.reshape(-1,1)) # teach the scalar the arr_delay values
hist_x = hist_x.transform(flights['arr_delay'].values.reshape(-1,1)) # transform the values on a scale from 0 to 1
hist_x = pd.DataFrame(hist_x) # convert to a dataframe to pass into sns object

rename_dict = {0 : 'arr_delay_scaled'} # creating a dictionary we will use in the next step (below)
hist_x = hist_x.rename(columns=rename_dict)  #  rename the column 0 to arr_ddelay_scaled for clarity (using dictionary from line above)
flights_arr_delay=(hist_x-hist_x.mean())/hist_x.std()
plt.xlim(-2, 2)
sns.histplot(data=flights_arr_delay, x="arr_delay_scaled")
# Out:
# <AxesSubplot:xlabel='arr_delay_scaled', ylabel='Count'>

# %% [markdown]
# ### The graph above looks skewed to the right - this is **not** a normal distribution.

# %%
mean_ = flights_arr_delay['arr_delay_scaled'].mean()
median_ = flights_arr_delay['arr_delay_scaled'].median()
mode_ = flights_arr_delay['arr_delay_scaled'].mode()[0]

# %%
print(f'mean: {mean_}')
print(f'median: {median_}')
print(f'mode: {mode_}')
#print('If the median and the mode are both to the LEFT of the mean, the distribution is RIGHT skewed. A Normal distribution would be symmetrical.')
# Out:
# mean: -4.961180886725863e-16
# median: -0.21651544001523523
# mode: -0.3048582970884991

# %%
three_sigma = []
for i in (flights_arr_delay['arr_delay_scaled']):
    if i < abs(flights_arr_delay['arr_delay_scaled'].std()*3):
        three_sigma.append(i)
    #print(i)
three_sigma = pd.DataFrame(three_sigma)

# %%
percentage_of_data_within_three_stds = len(three_sigma) / len(flights_arr_delay)
percentage_of_data_within_three_stds
# Out:
# 0.970774933319387

# %% [markdown]
# # Look at weather conditions

# %% [markdown]
# ### Conditions variables - could be used to identify delay types based on the weather

# %%
weather = flights[['origin_wind_speed', 'origin_visibility', 'origin_conditions', 'dest_wind_speed', 'dest_visibility' ,'dest_conditions']]

# %%
weather_conditions = weather[['origin_conditions', 'dest_conditions']]
weather_conditions_origin_conditions = weather_conditions['origin_conditions']
weather_conditions_origin_conditions = weather_conditions_origin_conditions.value_counts()

# %%
weather_conditions = weather[['origin_conditions', 'dest_conditions']]
weather_conditions_dest_conditions = weather_conditions['dest_conditions']
weather_conditions_dest_conditions = weather_conditions_dest_conditions.value_counts()

# %%
weather_conditions_totals = weather_conditions_origin_conditions + weather_conditions_dest_conditions
weather_conditions_totals
# Out:
# Partially cloudy          198412
# Clear                     133889
# Rain, Partially cloudy    117658
# Rain, Overcast             98617
# Overcast                   37865
# Snow, Partially cloudy     11584
# Snow, Overcast              7044
# Rain                        4668
# Snow                        2135
# dtype: int64

# %% [markdown]
# # Notes:
# - We may want to begin with the exploratory_analysis notebook to familiarize ourselves with the project (I think we should aim to answer as many as possible).
# - We will have to specify a target variable by identifying which flights are delayed, and quantify this value
# - We will need to eliminate all relevant columns from causing our data to be biased or overfitted (all delay columns need to be removed)
#
# Some ideas:
# - Check how many airports there are; how many flights per airport; how many passengers per flight
# - Do some airports have more delays than others?
# - Weather; how should we quantify this; by geographic area? magnitude (1-10)? What weather conditions should we look for? (might be worth a google to see what are common weather delays for flights in certain areas)
# - Time of day, day of week (weekend?)

# %%
# look for "delay" columns, add to dictionary with column number as key
delay_list = {}

for i, name in enumerate(flights.columns):
    if ('delay') in (name):
        #print(name)
        delay_list[i] = name

# %%
delay_list
# Out:
# {10: 'dep_delay',
#  11: 'arr_delay',
#  16: 'carrier_delay',
#  17: 'weather_delay',
#  18: 'nas_delay',
#  19: 'security_delay',
#  20: 'late_aircraft_delay'}

# %%
flights['arr_delay'].value_counts().mean()
# Out:
# 313.8170478170478

# %%
sns.histplot(data=flights, x="arr_delay")
plt.xlim(-100, 300)
# Out:
# (-100.0, 300.0)

# %%
df_filter = (flights['month'] == '12')
dec_flights = flights[df_filter].groupby(by=(['fl_date'])).mean()

# %%
df_filter = (flights['month'] == '12')
flights[df_filter]
# Out:
# Empty DataFrame
# Columns: [fl_date, mkt_carrier, origin_airport_id, origin_city_name, dest_airport_id, dest_city_name, crs_dep_time, crs_arr_time, dep_time, arr_time, dep_delay, arr_delay, crs_elapsed_time, actual_elapsed_time, air_time, distance, carrier_delay, weather_delay, nas_delay, security_delay, late_aircraft_delay, origin_wind_speed, origin_visibility, origin_conditions, dest_wind_speed, dest_visibility, dest_conditions, day_of_the_week, holiday, year, month, scheduled_flight_hour_of_day]
# Index: []

# %%
df_filter = (flights['month'] == '01')
jan_flights = flights[df_filter].groupby(by=(['fl_date'])).mean()

# %%
# **********
# DECEMBER
# year
year_vector = []
for i in dec_flights.index:
    year_vector.append(i[0:4])

dec_flights['year'] = year_vector

# day
day_vector = []
for i in dec_flights.index:
    #print((i[-2:]))
    day_vector.append(i[-2:])

dec_flights['day'] = day_vector


# **********
# JANUARY

# year
year_vector = []
for i in jan_flights.index:
    year_vector.append(i[0:4])

jan_flights['year'] = year_vector

# day
day_vector = []
for i in jan_flights.index:
    #print((i[-2:]))
    day_vector.append(i[-2:])

jan_flights['day'] = day_vector

# %%
#jan_flights[:60]

# %%
sns.set_style("darkgrid")
sns.lineplot(data=jan_flights, x='day', y='arr_delay', hue='year', estimator=None).set_title('January arr_delay')
# Out:
# Text(0.5, 1.0, 'January arr_delay')

# %%
sns.set_style("darkgrid")
sns.lineplot(data=dec_flights, x='day', y='arr_delay', hue='year', estimator=None).set_title('December arr_delay')
# Out:
# Text(0.5, 1.0, 'December arr_delay')

# %%
sns.set_style("darkgrid")
sns.boxplot(x='origin_city_name', y="arr_delay", data=flights).set_title('City arr_delay')
# Out:
# Text(0.5, 1.0, 'City arr_delay')

# %%
flights.columns
# Out:
# Index(['fl_date', 'mkt_carrier', 'origin_airport_id', 'origin_city_name',
#        'dest_airport_id', 'dest_city_name', 'crs_dep_time', 'crs_arr_time',
#        'dep_time', 'arr_time', 'dep_delay', 'arr_delay', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance', 'carrier_delay',
#        'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay',
#        'origin_wind_speed', 'origin_visibility', 'origin_conditions',
#        'dest_wind_speed', 'dest_visibility', 'dest_conditions',
#        'day_of_the_week', 'holiday', 'year', 'month',
#        'scheduled_flight_hour_of_day'],
#       dtype='object')

# %%
flights_test = flights.copy()

# %%
flights_test.columns
# Out:
# Index(['fl_date', 'mkt_carrier', 'origin_airport_id', 'origin_city_name',
#        'dest_airport_id', 'dest_city_name', 'crs_dep_time', 'crs_arr_time',
#        'dep_time', 'arr_time', 'dep_delay', 'arr_delay', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance', 'carrier_delay',
#        'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay',
#        'origin_wind_speed', 'origin_visibility', 'origin_conditions',
#        'dest_wind_speed', 'dest_visibility', 'dest_conditions',
#        'day_of_the_week', 'holiday', 'year', 'month',
#        'scheduled_flight_hour_of_day'],
#       dtype='object')
